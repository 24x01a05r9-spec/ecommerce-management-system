# %% [markdown]
# <a href="https://colab.research.google.com/github/24x01a05r9-spec/ecommerce-management-system/blob/main/Flask_E_Commerce_app_ipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask flask_sqlalchemy flask_login

# %%
# %%writefile app.py

from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return """
    <h1>🛒 E-Commerce Web App</h1>
    <h3>Project Running Successfully</h3>
    <p>Welcome Bavani</p>
    """

app.run(host='0.0.0.0', port=5000)
# Out:
# Overwriting app.py

# %%
# !python app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# Exception ignored in: <module 'threading' from '/usr/lib/python3.12/threading.py'>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1575, in _shutdown
#     def _shutdown():
#
# KeyboardInterrupt:
